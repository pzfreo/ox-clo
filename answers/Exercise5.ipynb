# %%
import numpy as np
import pandas as pd
dffull = pd.read_csv('file:///home/oxclo/hyg/hygdata_v3.csv')
dffull
# Out:
#             id  hip        hd  hr       gl   bf proper         ra        dec  \
# 0            0  NaN       NaN NaN      NaN  NaN    Sol   0.000000   0.000000
# 1            1  1.0  224700.0 NaN      NaN  NaN    NaN   0.000060   1.089009
# 2            2  2.0  224690.0 NaN      NaN  NaN    NaN   0.000283 -19.498840
# 3            3  3.0  224699.0 NaN      NaN  NaN    NaN   0.000335  38.859279
# 4            4  4.0  224707.0 NaN      NaN  NaN    NaN   0.000569 -51.893546
# ...        ...  ...       ...  ..      ...  ...    ...        ...        ...
# 119609  119611  NaN       NaN NaN  NN 4381  NaN    NaN  23.963895  38.629391
# 119610  119612  NaN       NaN NaN  NN 4385  NaN    NaN  23.996567  47.762093
# 119611  119613  NaN       NaN NaN  NN 4386  NaN    NaN  23.996218 -44.067905
# 119612  119614  NaN       NaN NaN  NN 4387  NaN    NaN  23.997386 -34.111986
# 119613  119615  NaN       NaN NaN   Gl 915  NaN    NaN   0.036059 -43.165974
#
#             dist  ...  bayer  flam  con  comp  comp_primary base         lum  \
# 0         0.0000  ...    NaN   NaN  NaN     1             0  NaN    1.000000
# 1       219.7802  ...    NaN   NaN  Psc     1             1  NaN    9.638290
# 2        47.9616  ...    NaN   NaN  Cet     1             2  NaN    0.392283
# 3       442.4779  ...    NaN   NaN  And     1             3  NaN  386.901132
# 4       134.2282  ...    NaN   NaN  Phe     1             4  NaN    9.366989
# ...          ...  ...    ...   ...  ...   ...           ...  ...         ...
# 119609   16.9492  ...    NaN   NaN  NaN     1        119611  NaN    0.002200
# 119610   16.7224  ...    NaN   NaN  NaN     1        119612  NaN    0.000088
# 119611   18.5185  ...    NaN   NaN  NaN     1        119613  NaN    0.002224
# 119612   12.8205  ...    NaN   NaN  NaN     1        119614  NaN    0.001086
# 119613    7.8003  ...    NaN   NaN  NaN     1        119615  NaN    0.000319
#
#         var  var_min  var_max
# 0       NaN      NaN      NaN
# 1       NaN      NaN      NaN
# 2       NaN      NaN      NaN
# 3       NaN      NaN      NaN
# 4       NaN      NaN      NaN
# ...     ...      ...      ...
# 119609  NaN      NaN      NaN
# 119610  NaN      NaN      NaN
# 119611  NaN      NaN      NaN
# 119612  NaN      NaN      NaN
# 119613  NaN      NaN      NaN
#
# [119614 rows x 37 columns]

# %%
# %config IPCompleter.greedy=True

# %%
dffull.shape
# Out:
# (119614, 37)

# %%
columns = ['id', 'gl','mag','absmag' , 'proper', 'ra', 'dec',
           'dist', 'con', 'ci', 'lum']
df = pd.DataFrame(dffull, columns = columns)
df
# Out:
#             id       gl    mag  absmag proper         ra        dec      dist  \
# 0            0      NaN -26.70   4.850    Sol   0.000000   0.000000    0.0000
# 1            1      NaN   9.10   2.390    NaN   0.000060   1.089009  219.7802
# 2            2      NaN   9.27   5.866    NaN   0.000283 -19.498840   47.9616
# 3            3      NaN   6.61  -1.619    NaN   0.000335  38.859279  442.4779
# 4            4      NaN   8.06   2.421    NaN   0.000569 -51.893546  134.2282
# ...        ...      ...    ...     ...    ...        ...        ...       ...
# 119609  119611  NN 4381  12.64  11.494    NaN  23.963895  38.629391   16.9492
# 119610  119612  NN 4385  16.10  14.984    NaN  23.996567  47.762093   16.7224
# 119611  119613  NN 4386  12.82  11.482    NaN  23.996218 -44.067905   18.5185
# 119612  119614  NN 4387  12.80  12.260    NaN  23.997386 -34.111986   12.8205
# 119613  119615   Gl 915  13.05  13.589    NaN   0.036059 -43.165974    7.8003
#
#         con     ci         lum
# 0       NaN  0.656    1.000000
# 1       Psc  0.482    9.638290
# 2       Cet  0.999    0.392283
# 3       And -0.019  386.901132
# 4       Phe  0.370    9.366989
# ...     ...    ...         ...
# 119609  NaN    NaN    0.002200
# 119610  NaN  1.870    0.000088
# 119611  NaN  1.640    0.002224
# 119612  NaN    NaN    0.001086
# 119613  NaN  0.070    0.000319
#
# [119614 rows x 11 columns]

# %%
df['proper'].dropna()
# Out:
# 0                   Sol
# 676           Alpheratz
# 744                Caph
# 1065            Algenib
# 2076              Ankaa
#               ...
# 113008        Fomalhaut
# 113521           Scheat
# 113603           Markab
# 113687    Lacaille 9352
# 118084        p Eridani
# Name: proper, Length: 146, dtype: object

# %%
df.loc[df['proper'].notnull()]
# Out:
#             id      gl    mag  absmag         proper         ra        dec  \
# 0            0     NaN -26.70   4.850            Sol   0.000000   0.000000
# 676        676     NaN   2.07  -0.297      Alpheratz   0.139791  29.090432
# 744        744    Gl 8   2.28   1.155           Caph   0.152887  59.149780
# 1065      1065     NaN   2.83  -2.567        Algenib   0.220598  15.183596
# 2076      2076     NaN   2.40   0.327          Ankaa   0.438056 -42.305981
# ...        ...     ...    ...     ...            ...        ...        ...
# 113008  113008  Gl 881   1.17   1.737      Fomalhaut  22.960838 -29.622236
# 113521  113521     NaN   2.44  -1.454         Scheat  23.062901  28.082789
# 113603  113603     NaN   2.49  -0.568         Markab  23.079348  15.205264
# 113687  113687  Gl 887   7.35   9.773  Lacaille 9352  23.097531 -35.853073
# 118084  118084  Gl 66A   5.80   6.245      p Eridani   1.663003 -56.194620
#
#             dist  con     ci         lum
# 0         0.0000  NaN  0.656    1.000000
# 676      29.7442  And -0.038  114.498553
# 744      16.7842  Cas  0.380   30.060763
# 1065    120.0480  Peg -0.190  926.403101
# 2076     25.9740  Phe  1.083   64.446598
# ...          ...  ...    ...         ...
# 113008    7.7036  PsA  0.145   17.587334
# 113521   60.0962  Peg  1.655  332.353304
# 113603   40.8831  Peg -0.002  146.960290
# 113687    3.2759  PsA  1.483    0.010735
# 118084    8.1466  Eri  0.860    0.276694
#
# [146 rows x 11 columns]

# %%
df.sort_values('dist', ascending=False)
# Out:
#             id       gl    mag  absmag            proper         ra  \
# 38104    38104      NaN   8.41 -11.590               NaN   7.828196
# 56934    56934      NaN   9.07 -10.930               NaN  11.706949
# 105463  105463      NaN   9.34 -10.660               NaN  21.427510
# 51482    51482      NaN   7.51 -12.490               NaN  10.547573
# 56943    56943      NaN   9.10 -10.900               NaN  11.708783
# ...        ...      ...    ...     ...               ...        ...
# 87665    87665   Gl 699   9.54  13.235    Barnard's Star  17.963472
# 71456    71456  Gl 559A  -0.01   4.379   Rigil Kentaurus  14.660765
# 71453    71453  Gl 559B   1.35   5.739               NaN  14.660346
# 70666    70666   Gl 551  11.01  15.447  Proxima Centauri  14.495985
# 0            0      NaN -26.70   4.850               Sol   0.000000
#
#               dec         dist  con     ci           lum
# 38104  -55.964381  100000.0000  Car  0.025  3.767038e+06
# 56934  -11.517968  100000.0000  Crt  1.292  2.051162e+06
# 105463 -39.186960  100000.0000  Mic  0.740  1.599558e+06
# 51482  -26.609447  100000.0000  Hya  1.640  8.629785e+06
# 56943   46.506604  100000.0000  UMa  1.047  1.995262e+06
# ...           ...          ...  ...    ...           ...
# 87665    4.693388       1.8238  Oph  1.570  4.425884e-04
# 71456  -60.833976       1.3248  Cen  0.710  1.543121e+00
# 71453  -60.838300       1.3248  Cen  0.900  4.409608e-01
# 70666  -62.679485       1.2959  Cen  1.807  5.770321e-05
# 0        0.000000       0.0000  NaN  0.656  1.000000e+00
#
# [119614 rows x 11 columns]

# %%
df.head(n=10)
# Out:
#    id   gl    mag  absmag proper        ra        dec      dist  con     ci  \
# 0   0  NaN -26.70   4.850    Sol  0.000000   0.000000    0.0000  NaN  0.656
# 1   1  NaN   9.10   2.390    NaN  0.000060   1.089009  219.7802  Psc  0.482
# 2   2  NaN   9.27   5.866    NaN  0.000283 -19.498840   47.9616  Cet  0.999
# 3   3  NaN   6.61  -1.619    NaN  0.000335  38.859279  442.4779  And -0.019
# 4   4  NaN   8.06   2.421    NaN  0.000569 -51.893546  134.2282  Phe  0.370
# 5   5  NaN   8.55   1.494    NaN  0.000665 -40.591202  257.7320  Phe  0.902
# 6   6  NaN  12.31   8.607    NaN  0.001246   3.946458   55.0358  NaN  1.336
# 7   7  NaN   9.64   5.828    NaN  0.001470  20.036114   57.8704  Peg  0.740
# 8   8  NaN   9.05   2.536    NaN  0.001823  25.886461  200.8032  Peg  1.102
# 9   9  NaN   8.59   0.473    NaN  0.002355  36.585958  420.1681  And  1.067
#
#           lum
# 0    1.000000
# 1    9.638290
# 2    0.392283
# 3  386.901132
# 4    9.366989
# 5   21.998851
# 6    0.031420
# 7    0.406256
# 8    8.425584
# 9   56.337815

# %%
max(df['dist'])
# Out:
# 100000.0

# %%
df.loc[(df['proper'].notnull()) & (df['dist']<=100000)].sort_values('dist', ascending = False)
# Out:
#             id       gl    mag  absmag                    proper         ra  \
# 60731    60731      NaN  12.88  -7.120                    3C 273  12.485193
# 111893  111893      NaN   8.83 -11.170            Babcock's star  22.735418
# 95992    95992      NaN  10.00 -10.000  Campbell's Hydrogen Star  19.579231
# 26176    26176      NaN   2.75  -6.519                    Hatsya   5.590551
# 25920    25920      NaN   2.58  -6.583                     Arneb   5.545504
# ...        ...      ...    ...     ...                       ...        ...
# 53879    53879   Gl 411   7.49  10.460             Lalande 21185  11.055632
# 87665    87665   Gl 699   9.54  13.235            Barnard's Star  17.963472
# 71456    71456  Gl 559A  -0.01   4.379           Rigil Kentaurus  14.660765
# 70666    70666   Gl 551  11.01  15.447          Proxima Centauri  14.495985
# 0            0      NaN -26.70   4.850                       Sol   0.000000
#
#               dec         dist  con     ci           lum
# 60731    2.052398  100000.0000  NaN  0.120  6.137620e+04
# 111893  55.589226  100000.0000  Lac  0.031  2.558586e+06
# 95992   30.516371  100000.0000  Cyg -0.013  8.709636e+05
# 26176   -5.909901     714.2857  Ori -0.210  3.528580e+04
# 25920  -17.822289     680.2721  Lep  0.211  3.742829e+04
# ...           ...          ...  ...    ...           ...
# 53879   35.969877       2.5469  UMa  1.502  5.701643e-03
# 87665    4.693388       1.8238  Oph  1.570  4.425884e-04
# 71456  -60.833976       1.3248  Cen  0.710  1.543121e+00
# 70666  -62.679485       1.2959  Cen  1.807  5.770321e-05
# 0        0.000000       0.0000  NaN  0.656  1.000000e+00
#
# [146 rows x 11 columns]

# %%
df.sort_values('lum', ascending=True).head(n=3)['gla']
# Out:
#             id       gl    mag  absmag proper         ra        dec     dist  \
# 118970  118972  NN 3849  19.74  19.629    NaN  14.478657  33.176703  10.5263
# 119180  119182  NN 4029  20.10  19.237    NaN  17.833107  22.683357  14.8810
# 118570  118572  NN 3517  18.80  19.137    NaN   8.893343  -3.490080   8.5616
#
#         con  ci       lum
# 118970  NaN NaN  0.000001
# 119180  NaN NaN  0.000002
# 118570  NaN NaN  0.000002

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt

# %%
df.plot()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.plot.scatter(x='dist', y='lum')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.loc[df['dist'] <100000].plot.scatter(x='dist', y='lum')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df.loc[df['dist'] <100000].plot.scatter(x='dist', y='lum' , logx=True, logy=True)
# Out:
# <img src="data:image/png;base64,..." width="640">
